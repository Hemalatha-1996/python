# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
# !pip  install openpyxl

# %%
df=pd.read_excel(r"E:\Data analyst\python\data analyst_python\projects\Test_set.xlsx")

# %%
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %%
df.describe()
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count          2671            2671   2671        2671             2671
# unique           11              44      5           6              100
# top     Jet Airways       9/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq            897             144   1145        1145              624
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count      2671         2671     2671        2671            2671
# unique      199          704      320           5               6
# top       10:00        19:00   2h 50m      1 stop         No info
# freq         62          113      122        1431            2148

# %%
df['Journey_date']=df['Date_of_Journey'].str.split("/").str[0]
df['Journey_month']=df['Date_of_Journey'].str.split("/").str[1]
df['Journey_year']=df['Date_of_Journey'].str.split("/").str[2]

# %%
df["Journey_month"]=df["Journey_month"].astype(int)
df["Journey_year"]=df["Journey_year"].astype(int)
df["Journey_date"]=df["Journey_date"].astype(int)

# %%
df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Source           2671 non-null   object
#  2   Destination      2671 non-null   object
#  3   Route            2671 non-null   object
#  4   Dep_Time         2671 non-null   object
#  5   Arrival_Time     2671 non-null   object
#  6   Duration         2671 non-null   object
#  7   Total_Stops      2671 non-null   object
#  8   Additional_Info  2671 non-null   object
#  9   Journey_date     2671 non-null   int64
#  10  Journey_month    2671 non-null   int64
#  11  Journey_year     2671 non-null   int64
# dtypes: int64(3), object(9)
# memory usage: 250.5+ KB

# %%
df.head(2)
# Out:
#        Airline   Source Destination            Route Dep_Time  Arrival_Time  \
# 0  Jet Airways    Delhi      Cochin  DEL → BOM → COK    17:30  04:25 07 Jun
# 1       IndiGo  Kolkata    Banglore  CCU → MAA → BLR    06:20         10:20
#
#   Duration Total_Stops Additional_Info  Journey_date  Journey_month  \
# 0  10h 55m      1 stop         No info             6              6
# 1       4h      1 stop         No info            12              5
#
#    Journey_year
# 0          2019
# 1          2019

# %%
df["Dep_hour"]=df['Dep_Time'].str.split(":").str[0].astype(int)
df["Dep_minute"]=df['Dep_Time'].str.split(":").str[1].astype(int)

# %%
df.head(2)
# Out:
#        Airline   Source Destination            Route Dep_Time  Arrival_Time  \
# 0  Jet Airways    Delhi      Cochin  DEL → BOM → COK    17:30  04:25 07 Jun
# 1       IndiGo  Kolkata    Banglore  CCU → MAA → BLR    06:20         10:20
#
#   Duration Total_Stops Additional_Info  Journey_date  Journey_month  \
# 0  10h 55m      1 stop         No info             6              6
# 1       4h      1 stop         No info            12              5
#
#    Journey_year  Dep_hour  Dep_minute
# 0          2019        17          30
# 1          2019         6          20

# %%
df.drop("Dep_Time",axis=1,inplace=True)

# %%
df.head(2)
# Out:
#        Airline   Source Destination            Route  Arrival_Time Duration  \
# 0  Jet Airways    Delhi      Cochin  DEL → BOM → COK  04:25 07 Jun  10h 55m
# 1       IndiGo  Kolkata    Banglore  CCU → MAA → BLR         10:20       4h
#
#   Total_Stops Additional_Info  Journey_date  Journey_month  Journey_year  \
# 0      1 stop         No info             6              6          2019
# 1      1 stop         No info            12              5          2019
#
#    Dep_hour  Dep_minute
# 0        17          30
# 1         6          20

# %%
df["Arrival_Time"]=df["Arrival_Time"].apply(lambda x:x.split(" ")[0])

# %%
df["Arrival_hour"]=df["Arrival_Time"].str.split(":").str[0]
df["Arrival_minute"]=df["Arrival_Time"].str.split(":").str[1]

# %%
df.drop("Arrival_Time",axis=1,inplace=True)

# %%
df["Total_Stops"] = df["Total_Stops"].map({
    "non stop": "0",
    "1 stop": "1",
    "2 stops": "2",
    "3 stops": "3",
    "4 stops": "4"
})

# Then fill missing values (NaNs)
df["Total_Stops"] = df["Total_Stops"].fillna("1").astype(int)

# %%
df["Total_Stops"].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#    Total_Stops              Additional_Info  Journey_date  Journey_month  \
# 0            1                      No info             6              6
# 1            1                      No info            12              5
# 2            1  In-flight meal not included            21              5
# 3            1                      No info            21              5
# 4            1                      No info            24              6
#
#    Journey_year  Dep_hour  Dep_minute Arrival_hour Arrival_minute
# ...

# %%
df.drop('Route',axis=1,inplace=True)

# %%
df.head()
# Out:
#              Airline    Source Destination Duration  Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  10h 55m            1
# 1             IndiGo   Kolkata    Banglore       4h            1
# 2        Jet Airways     Delhi      Cochin  23h 45m            1
# 3  Multiple carriers     Delhi      Cochin      13h            1
# 4           Air Asia  Banglore       Delhi   2h 50m            1
#
#                Additional_Info  Journey_date  Journey_month  Journey_year  \
# 0                      No info             6              6          2019
# 1                      No info            12              5          2019
# 2  In-flight meal not included            21              5          2019
# 3                      No info            21              5          2019
# 4                      No info            24              6          2019
#
#    Dep_hour  Dep_minute Arrival_hour Arrival_minute
# 0        17          30           04             25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Source           2671 non-null   object
#  2   Destination      2671 non-null   object
#  3   Duration         2671 non-null   object
#  4   Total_Stops      2671 non-null   int64
#  5   Additional_Info  2671 non-null   object
#  6   Journey_date     2671 non-null   int64
#  7   Journey_month    2671 non-null   int64
#  8   Journey_year     2671 non-null   int64
#  9   Dep_hour         2671 non-null   int64
#  10  Dep_minute       2671 non-null   int64
#  11  Arrival_hour     2671 non-null   object
#  12  Arrival_minute   2671 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 271.4+ KB

# %%
stops={"1 stop":'1','non_stop':'0','2 stops':'2','3 stops':'3','4 stops':'4'}
df["Total_Stops"]=df["Total_Stops"].map(stops)

# %%
stops={"1 stop":'1','non_stop':'0','2 stops':'2','3 stops':'3','4 stops':'4'}
df["Total_Stops"]=df["Total_Stops"].map(stops)
